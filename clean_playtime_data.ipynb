# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/levimunster/Desktop/VS_Code/MiddleburyCS/stat0350/playtime/playtime_21:48:42.csv')

# %%
df['Game'][49]
# Out:
# 'Totally Accurate Battle Simulator'

# %%
df['main'] = df['main'].str.replace('½', '.5', regex=False)
df['main_sides'] = df['main_sides'].str.replace('½', '.5', regex=False)
df['completionist'] = df['completionist'].str.replace('½', '.5', regex=False)

# %%
df['Game'] = [
 'happyroom_550010',
 'spongebobsquarepantsthecosmicshake_1282150',
 'blitzkrieg3_235380',
 'theescapists_298630',
 'trainsimworld3_1944790',
 'trainsimworld2_1282590',
 'themortuaryassistant_1295920',
 'marvelspidermanremastered_1817070',
 'onepieceworldseeker_755500',
 'projectwingman_895870',
 'metalgearsolid5groundzeroes_311340',
 'mafiadefininiteedition_1030840',
 'paganabsentgods_992640',
 'endzoneaworldapart_933820',
 'pizzaconnection3_588160',
 'shadowofthetombraider_750920',
 'wolfstein2newcolossus_612880',
 'clusterstruck_397950',
 'residentevil0_339340',
 'suddenstrike4_373930',
 'metro2033redux_286690',
 'fateextella_511680',
 'hitmanabsolution_203140',
 'destroyallhumans_803330',
 'theroom4oldsins_1361320',
 'surgeonsimulator2_774791',
 'ninokuni2revenantkingdom_589360',
 'fishingnorthatlantic_1264250',
 'gearstactics_1184050',
 'theyarebillions_644930',
 'internetcafesimulator_1136160',
 'fishingbarentssea_501080',
 'sandsofsalzaar_1094520',
 'metroexodus_412020',
 'marvelsguardiansofthegalaxy_1088850',
 'justcause3_225540',
 'motorsportmanager_415200',
 'layersoffear_1946700',
 'thronebreakerthewitchertales_973760',
 'myfriendpedro_557340',
 'thebeastinside_792300',
 'blairwitch_1092660',
 'internetcafesimulator2_1563180',
 'breathedge_738520',
 'jurassicworldevolution2_1244460',
 'sniperghostwarriorcontracts2_1338770',
 'forager_751780',
 'storyofseasonsfriendsofmineraltown_978780',
 'assassinscreedorigins_582160',
 'totaltanksimulator_674500',
 'assassinscreedvalhalla_2208920',
 'thewalkingdeadsaintsandsinners_916840',
 'battleroyaletrainer_772540',
 'crysisremastered_1715130',
 'assassinscreedodyssey_812140',
 'coldsymmetry_1110910',
 'circleempires_834740',
 'riseofthetombraider_391220',
 'dinorundx_248330',
 'brightmemory_955050',
 'brightmemoryinfinite_1178830',
 'trainsimworld2020_530070',
 'landofthevikings_1981570',
 'lawnmowingsimulator_1480560',
 'barrierx_463150',
 'jurassicworldevolution_648350',
 'transportfever_446800',
 'thesurge2_644830',
 'estrangedthedepature_582890',
 'citycardriving_493490',
 'justcause2_8190',
 'batmanarkhamorigins_209000',
 'outlast_238320',
 'citiesskylines2_949230',
 'anno2205_375910',
 'adanceoffireandice_977950',
 'prisonarchitect_233450',
 'zombiesonaplane_297450',
 'crazymachines3_351920',
 'sherlockhomesthedevilsdaughter_350640',
 'omonsimulator_1140440',
 'yonderthecloudcatcherchronicles_580200',
 'subnauticabelowzero_848450',
 'residentevilvillage_1196590',
 'professionalfarmercattleandcrops_704030',
 'rollercoastertycoonworld_282560',
 'beamngdrive_284160',
 'talesofarise_740130',
 'daysgone_1259420',
 'dragonsdogmadarkariser_367500',
 'ancestorysthehumankindodyssey_536270',
 'possessed_607210',
 'planetzoo_703080',
 'madmax_234140',
 'thebureauxcomdeclassified_65930',
 'crashbandicootnsanetrilogy_731490',
 'residentevil7biohazard_418370',
 'qop2_757330',
 'dawnofman_858810',
 'subnautica_264710',
 'ultimategeneralcivilwar_502520',
 'catquest_593280',
 'rage2_548570',
 'teardown_1167630',
 'mafia3definitiveedition_360430',
 'visage_594330',
 'iced_575570',
 'littlenightmares2_860510',
 'marvelspidermanmilesmorales_1817190',
 'monsterslayers_905690',
 'fairytail_1233260',
 'theifsimulator2prologue_2272420',
 'deathstrandingdirectorscut_1850570',
 'bloodyspell_992300',
 'dungreed_753420',
 'stateofdecay_241540',
 'wolfsteinoldblood_350080',
 'halflife2_220',
 'residentevil2_883710',
 'planetcoaster_493340',
 'houseflipper_613100',
 'ISLANDERS',
 'unchartedlegacyofthieves_1659420',
 'otherworldsindia_576050',
 'carmechanicsimulator_1190000',
 'worldoffinalfantasy_552700',
 'finalfantasytype0_340170',
 'greedfall_606880',
 'biomutant_597820',
 'dragonballzkararot_851850',
 'hackme_526740',
 'skatesim_861650',
 'bioshock2remastered_409720',
 'stateofdecayyearone_329430',
 'survivingtheaftermath_684450',
 'gujian3_994280',
 'middleearthshadowofwar_356190',
 'hotuloshuthebooksofdragon_952860',
 'mirrorsedgecatalyst_1233570',
 'starwarsjedisurvivor_1774580'
]

# %%
df.to_csv('/Users/levimunster/Desktop/VS_Code/MiddleburyCS/stat0350/clean_data/playtime_clean.csv', index=False)
