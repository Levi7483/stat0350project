# %%
import pandas as pd

# %%
retention_df = pd.read_csv('/Users/levimunster/Desktop/VS_Code/MiddleburyCS/stat0350/clean_data/clean_retention2.csv')
achievement_df = pd.read_csv('/Users/levimunster/Desktop/VS_Code/MiddleburyCS/stat0350/clean_data/clean_achievement_data.csv')
playtime_df = pd.read_csv('/Users/levimunster/Desktop/VS_Code/MiddleburyCS/stat0350/clean_data/playtime_clean.csv')

# %%
analysis_df = pd.merge(pd.merge(retention_df, achievement_df, on='game'),playtime_df)

# %%
analysis_df.drop(columns=['D1_n', 'D7_n', 'D30_n', 'D360_n', 'D720_n'], axis=1).to_csv('analysis2.csv',index=False)

# %%
analysis_df
# Out:
#                                            game   peak_n   peak_date  \
# 0                              happyroom_550010   1414.0  2017-01-15
# 1    spongebobsquarepantsthecosmicshake_1282150   1949.0  2023-01-31
# 2                            blitzkrieg3_235380   1149.0  2017-07-21
# 3                           theescapists_298630   3312.0  2015-02-14
# 4                        trainsimworld3_1944790   1796.0  2023-03-26
# ..                                          ...      ...         ...
# 137                 mirrorsedgecatalyst_1233570   1446.0  2020-06-07
# 138                        residentevil2_883710  74227.0  2019-01-26
# 139                starwarsjedisurvivor_1774580  67855.0  2023-04-30
# 140                        planetcoaster_493340  21956.0  2016-11-20
# 141                         houseflipper_613100  15910.0  2023-10-08
#
#          D1_r      D7_r     D30_r    D360_r    D720_r     D1_n     D7_n  \
# ...
